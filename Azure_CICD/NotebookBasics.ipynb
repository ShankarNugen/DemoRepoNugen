# %%
print("Hello World")

# %%
# %sql
SELECT "Hello World from SQL!"

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# text with a **bold** and _italicized_ in it.
#
# ordered list
# 1. first
# 1. second
# 1. third
#
# Unordered list
# * coffee
# * tea
# * milk
#
# Images:
# ![Associate Badge](https://databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)
#
# And of course, tables:
#
# | user-id | user-name |
# |---------|-----------|
# |    1    |   Adam    |
# |    2    |   Sarah   |
# |    3    |   John    |

# %%
# %run ../Includes/5etup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
files = dbutils.fs.ls("/databricks-datasets")
print(files)

# %%
display(files)
